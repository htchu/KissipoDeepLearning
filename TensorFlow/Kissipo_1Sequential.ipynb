# %% [markdown]
# # Kissipo-DNN-Mnist(1)
# MNIST 手寫數字辨識
# ![Mnist](https://camo.githubusercontent.com/01c057a753e92a9bc70b8c45d62b295431851c09cffadf53106fc0aea7e2843f/687474703a2f2f692e7974696d672e636f6d2f76692f3051493378675875422d512f687164656661756c742e6a7067)

# %% [markdown]
# ##  載入TF2.0所需的函數庫

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# # Part-1 The training phase

# %% [markdown]
# ## IPO-M: Building a DL model (Sequential API, Graph mode)
# $M(x)=\hat{y}$

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10)
])

# %% [markdown]
# ## IPO-I: input data

# %% [markdown]
# ### 載入MNIST數據集。

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
type(x_train)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# ## IPO-O: ontput data

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000,)
# (10000,)

# %% [markdown]
# ## IPO-P: Training model

# %% [markdown]
# ###  選擇一個優化器和損失函數進行模型建構
# The from_logits=True attribute inform the loss function that the output values generated by the model are not normalized, a.k.a. logits. In other words, the softmax function has not been applied on them to produce a probability distribution.

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
#Create an optimizer with the desired parameters.
opt = tf.keras.optimizers.SGD(learning_rate=0.1)

# %% [markdown]
# ### Compile model

# %%
model.compile(optimizer=opt, loss=loss_fn, metrics=['accuracy'])

# %% [markdown]
# ##  進行模型訓練

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 2ms/step - loss: 0.2980 - accuracy: 0.9143
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1432 - accuracy: 0.9583
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1032 - accuracy: 0.9700
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0818 - accuracy: 0.9761
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0673 - accuracy: 0.9803
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0569 - accuracy: 0.9835
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0484 - accuracy: 0.9858
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0410 - accuracy: 0.9881
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0356 - accuracy: 0.9900
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0303 - accuracy: 0.9920

# %% [markdown]
# ## IPO-P: Evaluating model (模型評估)

# %%
model.evaluate(x_test,  y_test)

# %%
import numpy as np
from PIL import Image
from IPython.display import display

# %% [markdown]
# # Part-2 The Inference phase

# %% [markdown]
# ## IPO-M: Predicting the digit of an image
# $M(x)=\hat{y}$

# %% [markdown]
# ## IPO-I2: input a single image

# %%
### 第一次

# %%
#show image real size
img = Image.open('n1.bmp')
display(img)
img2=img.resize((28, 28))
img.close()

# %%
#show image at the size of 28x28
display(img2)

# %% [markdown]
# ### Covert an image to a numpy.ndarray (1, 28, 28)

# %%
im2arr = np.array(img2)/ 255.0
im2arr = im2arr.reshape(1,28,28)

# %% [markdown]
# ## IPO-P2: model.predict

# %%
y_pred = model.predict(im2arr)
print(y_pred)

# %%
y_hat =np.argmax(y_pred)
y_hat
